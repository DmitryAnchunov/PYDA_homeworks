# %% [markdown]
# #### Задание 1
#
# Получить интуицию, на что влияют параметры распределений.
#
# Построить по 5 функций плотностей с разными параметрами для каждого распределения:
#
# Нормальное, Экспоненциальное, Стьюдента на одном графике.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %matplotlib inline

# %% [markdown]
# ### Нормальное распределение
#
# Параметры в scipy.stats:
#
# loc =  $\mu$, математическое ожидание
#
# scale = 𝜎, дисперсия, среднеквадратичное отклонение

# %%
grid = np.linspace(-7, 7, 500) # сетка для построения графика
loc_values = [0, 0, 2, 2, 4] # набор значений параметра 𝜇
scale_values = [4, 2, 2, 0.5, 0.5] # набор значений параметра 𝜎

plt.figure(figsize=(12, 6))

for i, (lc, sc) in enumerate(zip(loc_values, scale_values)):
 plt.plot(grid, sts.norm(lc, sc).pdf(grid), lw=3,
 label='$\mathcal{Param}' + '({}, {})$'.format(lc, sc))

plt.legend(fontsize=16)
plt.title('Плотности нормального распределения', fontsize=20)
plt.xlabel('Значение', fontsize=18)
plt.ylabel('Плотность', fontsize=18)
plt.show()

# %% [markdown]
# ### Экспоненциальное распределение
#
# Параметры в scipy.stats:
#
# loc =  сдвиг
#
# scale = масштабирование

# %%
grid = np.linspace(0,5, 100, 500) # сетка для построения графика
loc_values = [0.5, 0.5, 1, 1, 2] # набор значений параметра loc
scale_values = [5, 3, 3, 2, 2] # набор значений параметра scale

plt.figure(figsize=(12, 6))

for i, (lc, sc) in enumerate(zip(loc_values, scale_values)):
 plt.plot(grid, sts.expon(lc, sc).pdf(grid), lw=3,
 label='$\mathcal{Param}' + '({}, {})$'.format(lc, sc))

plt.legend(fontsize=16)
plt.title('Плотности экспоненциального распределения', fontsize=20)
plt.xlabel('Значение', fontsize=18)
plt.ylabel('Плотность', fontsize=18)
plt.show()

# %% [markdown]
# ### Распределение Стьюдента
#
# Параметры в scipy.stats:
#
# df = параметр степеней свободы
#
# loc =  сдвиг
#
# scale = масштабирование

# %%
grid = np.linspace(0,5, 100, 500) # сетка для построения графика
df_values = [2, 5, 5, 5, 50] # набор значений параметра df
loc_values = [3, 3, 1, 1, 1] # набор значений параметра loc
scale_values = [0.5, 0.5, 0.5, 1, 1] # набор значений параметра scale

plt.figure(figsize=(12, 6))

for i, (df, lc, sc) in enumerate(zip(df_values, loc_values, scale_values)):
 plt.plot(grid, sts.t(df, lc, sc).pdf(grid), lw=3,
 label='$\mathcal{Param}' + '({}, {}, {})$'.format(df, lc, sc))

plt.legend(fontsize=16)
plt.title('Плотности распределения Стьюдента', fontsize=20)
plt.xlabel('Значение', fontsize=18)
plt.ylabel('Плотность', fontsize=18)
plt.show()
